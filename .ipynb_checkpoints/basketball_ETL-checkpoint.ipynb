# %%
# Import Dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine,inspect
import os
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# read player_allstar csv file, drop unnecessary columns
csv_file="resources/basketball_player_allstar.csv"
players_df=pd.read_csv(csv_file)
players_df=players_df[["player_id","last_name","first_name"]]
# drop duplicates and set player_id as index
players_df.drop_duplicates("player_id",inplace=True)
players_df.set_index("player_id", inplace=True)
players_df
# Out:
#               last_name first_name
# player_id
# abdulka01  Abdul-Jabbar     Kareem
# abdursh01       A-Rahim    Shareef
# adamsal01         Adams      Alvan
# adamsmi01         Adams    Michael
# aguirma01       Aguirre       Mark
# ...                 ...        ...
# wintebr01       Winters      Brian
# wisewi01           Wise     Willie
# worthja01        Worthy      James
# yardlge01       Yardley     George
# zasloma01     Zaslofsky        Max
#
# [450 rows x 2 columns]

# %%
# read player_awards csv file, drop unnecessary columns
csv_file="resources/basketball_awards_players.csv"
awards_df=pd.read_csv(csv_file)
awards_df=awards_df[["playerID","award","year"]]
# rename column playerID
awards_df.columns=["player_id","award","year"]
awards_df
# Out:
#       player_id                 award  year
# 0     feeribo01    All-NBA First Team  1946
# 1     fulksjo01    All-NBA First Team  1946
# 2     mckinho01    All-NBA First Team  1946
# 3     miasest01    All-NBA First Team  1946
# 4     zasloma01    All-NBA First Team  1946
# ...         ...                   ...   ...
# 1714  mikange01    Rookie of the Year  1945
# 1715  lewisfr01    Rookie of the Year  1946
# 1716  todormi01    Rookie of the Year  1947
# 1717  schaydo01    Rookie of the Year  1948
# 1718  hawkico01  Most Valuable Player  1961
#
# [1719 rows x 3 columns]

# %%
# read csv file of salaries and drop unnecessary columns
csv_file="resources/salaries_1985to2018.csv"
salary_df=pd.read_csv(csv_file)
salary_df=salary_df[["player_id","season","salary",]]
salary_df
# Out:
#        player_id   season   salary
# 0      abdelal01  1990-91   395000
# 1      abdelal01  1991-92   494000
# 2      abdelal01  1992-93   500000
# 3      abdelal01  1993-94   805000
# 4      abdelal01  1994-95   650000
# ...          ...      ...      ...
# 14158  zipsepa01  2016-17   750000
# 14159  zipsepa01  2017-18  1312611
# 14160  zizican01  2017-18  1645200
# 14161  zubaciv01  2016-17  1034956
# 14162  zubaciv01  2017-18  1312611
#
# [14163 rows x 3 columns]

# %%
# create database connection
password=os.environ.get("PASSWORD")
engine= create_engine('postgresql://postgres:'+password+'@localhost:5432/basketball_db')
connection=engine.connect()
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['players', 'awards', 'salaries']

# %%
# load dataframe into database
try:
    players_df.to_sql(name="players",con=engine,if_exists="append")
except:
    print("Table is already updated")
# Out:
# Table is already updated

# %%
# query table to confirm dataframe is loaded into database
pd.read_sql_query('select * from players', con=engine).head()
# Out:
#    player_id     last_name first_name
# 0  abdulka01  Abdul-Jabbar     Kareem
# 1  abdursh01       A-Rahim    Shareef
# 2  adamsal01         Adams      Alvan
# 3  adamsmi01         Adams    Michael
# 4  aguirma01       Aguirre       Mark

# %%
# set index to awards_df
awards_df["id"]=range(1,len(awards_df)+1)
awards_df.set_index("id",inplace=True)
awards_df
# Out:
#       player_id                 award  year
# id
# 1     feeribo01    All-NBA First Team  1946
# 2     fulksjo01    All-NBA First Team  1946
# 3     mckinho01    All-NBA First Team  1946
# 4     miasest01    All-NBA First Team  1946
# 5     zasloma01    All-NBA First Team  1946
# ...         ...                   ...   ...
# 1715  mikange01    Rookie of the Year  1945
# 1716  lewisfr01    Rookie of the Year  1946
# 1717  todormi01    Rookie of the Year  1947
# 1718  schaydo01    Rookie of the Year  1948
# 1719  hawkico01  Most Valuable Player  1961
#
# [1719 rows x 3 columns]

# %%
# load awards dataframe into database
try:
    players_df.to_sql(name="awards",con=engine,if_exists="append")
except:
    print("Table is already updated")
# Out:
# Table is already updated

# %%
# query table to confirm dataframe is loaded into database
pd.read_sql_query('select * from awards', con=engine).head()
# Out:
#    id  player_id               award  year
# 0   1  feeribo01  All-NBA First Team  1946
# 1   2  fulksjo01  All-NBA First Team  1946
# 2   3  mckinho01  All-NBA First Team  1946
# 3   4  miasest01  All-NBA First Team  1946
# 4   5  zasloma01  All-NBA First Team  1946

# %%
# set index to salary_df
salary_df["id"]=range(1,len(salary_df)+1)
salary_df.set_index("id",inplace=True)
salary_df
# Out:
#        player_id   season   salary
# id
# 1      abdelal01  1990-91   395000
# 2      abdelal01  1991-92   494000
# 3      abdelal01  1992-93   500000
# 4      abdelal01  1993-94   805000
# 5      abdelal01  1994-95   650000
# ...          ...      ...      ...
# 14159  zipsepa01  2016-17   750000
# 14160  zipsepa01  2017-18  1312611
# 14161  zizican01  2017-18  1645200
# 14162  zubaciv01  2016-17  1034956
# 14163  zubaciv01  2017-18  1312611
#
# [14163 rows x 3 columns]

# %%
# load salary dataframe into database
try:
    salary_df.to_sql(name="salaries",con=engine,if_exists="append")
except:
    print("Table is already updated")
# Out:
# Table is already updated

# %%
# query table to confirm dataframe is loaded into database
pd.read_sql_query('select * from salaries', con=engine).head()
# Out:
#    id  player_id   season  salary
# 0   1  abdelal01  1990-91  395000
# 1   2  abdelal01  1991-92  494000
# 2   3  abdelal01  1992-93  500000
# 3   4  abdelal01  1993-94  805000
# 4   5  abdelal01  1994-95  650000

# %%
# query about each player's count of awards and his average salary
awards_salary=pd.read_sql_query('''select t1.player_id,awards_count,max_salary
                             from(
                                  select awards.player_id,count(awards.award) as awards_count
                                  from awards
                                  group by awards.player_id)as t1
                              inner join( 
                                  select salaries.player_id,max(salary) as max_salary
                                  from salaries 
                                  group by salaries.player_id
                              ) as t2 on t1.player_id = t2.player_id''',con=engine)

awards_salary
# Out:
#      player_id  awards_count  max_salary
# 0     noahjo01             1    17765000
# 1    stojape01             1    14896000
# 2    bynuman01             1    16889000
# 3     rosede01             4    21323250
# 4    coopemi01             9      676500
# ..         ...           ...         ...
# 272  gervige01             9      831000
# 273  johnsla02             2    11910714
# 274  flynnjo01             1     3414720
# 275   wadedw01            11    23200000
# 276  jordami01            33    33140000
#
# [277 rows x 3 columns]

# %%
# get columns from player dataframe
players_df.reset_index(inplace=True)
players_df=players_df[["player_id","last_name","first_name"]]
players_df
# Out:
#      player_id     last_name first_name
# 0    abdulka01  Abdul-Jabbar     Kareem
# 1    abdursh01       A-Rahim    Shareef
# 2    adamsal01         Adams      Alvan
# 3    adamsmi01         Adams    Michael
# 4    aguirma01       Aguirre       Mark
# ..         ...           ...        ...
# 445  wintebr01       Winters      Brian
# 446   wisewi01          Wise     Willie
# 447  worthja01        Worthy      James
# 448  yardlge01       Yardley     George
# 449  zasloma01     Zaslofsky        Max
#
# [450 rows x 3 columns]

# %%
# merge palyers_df and awards_salary
all_data=player_df.merge(awards_salary,on="player_id", how="inner")
all_data
# Out:
#      player_id     last_name first_name  awards_count  max_salary
# 0    abdulka01  Abdul-Jabbar     Kareem            35     3000000
# 1    adamsal01         Adams      Alvan             1      675000
# 2    aingeda01         Ainge      Danny             1     2080000
# 3    allenra02         Allen        Ray             2    18776860
# 4    anthoca01       Anthony    Carmelo             5    26243760
# ..         ...           ...        ...           ...         ...
# 136  wilkido01       Wilkins  Dominique             7     3500000
# 137  willibu01      Williams       Buck             6     5050000
# 138  willide01      Williams      Deron             2    19754465
# 139  willigu01      Williams        Gus             3      790000
# 140  worthja01        Worthy      James             3     1850000
#
# [141 rows x 5 columns]

# %%
# top players with more than 10 awards
top_awards_count=all_data.loc[all_data["awards_count"]>10]
top_awards_count.sort_values(by="awards_count",ascending=False)
# Out:
#      player_id     last_name first_name  awards_count  max_salary
# 0    abdulka01  Abdul-Jabbar     Kareem            35     3000000
# 66   jordami01        Jordan    Michael            33    33140000
# 32   duncati01        Duncan        Tim            32    22183220
# 17   bryanko01        Bryant       Kobe            29    30453805
# 95   olajuha01      Olajuwon     Hakeem            26    16700000
# 41   garneke01       Garnett      Kevin            23    28000000
# 112  robinda01      Robinson      David            21    14841000
# 74   malonka01        Malone       Karl            20    19250000
# 11    birdla01          Bird      Larry            19     7070000
# 37   ervinju01        Erving     Julius            19     1485000
# 99   paytoga01        Payton       Gary            19    12926493
# 102  pippesc01        Pippen    Scottie            17    19727524
# 68    kiddja01          Kidd      Jason            17    21372000
# 57   jamesle01         James     LeBron            17    33285709
# 63   johnsma02       Johnson    Marques            16     3142860
# 125  stockjo01      Stockton       John            16    11000000
# 130  wallabe01       Wallace        Ben            15    16000000
# 75   malonmo01        Malone      Moses            14     2406000
# 90   mutomdi01       Mutombo    Dikembe            14    16105264
# 93   nowitdi01      Nowitzki       Dirk            14    25000000
# 52   howardw01        Howard     Dwight            14    23500000
# 64   jonesbo01         Jones      Bobby            13      500000
# 44   gilmoar01       Gilmore      Artis            13      863000
# 8    barklch01       Barkley    Charles            12     9000000
# 59   johnsde01       Johnson     Dennis            12      835500
# 87   moncrsi01      Moncrief     Sidney            12     1100000
# 114  rodmade01        Rodman     Dennis            12     9000000
# 38   ewingpa01         Ewing    Patrick            11    20500000
# 129   wadedw01          Wade     Dwyane            11    23200000

# %%
# top salaries
top_salaries=all_data.sort_values(by="max_salary",ascending=False).head(10)
top_salaries
# Out:
#     player_id last_name first_name  awards_count  max_salary
# 57  jamesle01     James     LeBron            17    33285709
# 66  jordami01    Jordan    Michael            33    33140000
# 17  bryanko01    Bryant       Kobe            29    30453805
# 41  garneke01   Garnett      Kevin            23    28000000
# 51  horfoal01   Horford         Al             2    27734405
# 33  duranke01    Durant      Kevin             5    26540100
# 4   anthoca01   Anthony    Carmelo             5    26243760
# 15   boshch01      Bosh      Chris             1    25289390
# 93  nowitdi01  Nowitzki       Dirk            14    25000000
# 61  johnsjo02   Johnson        Joe             1    24894863

# %%
# scatter plot and regression about awards_count and max_salary
x_values=all_data["awards_count"]
y_values=all_data["max_salary"]
r_value=st.pearsonr(x_values,y_values)[0]
print("The correlation between max salary and awards count is "
      +str(round(r_value,2)))
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10000000),fontsize=12)
plt.title("Max Salary vs. Awards Count for each Player",fontsize=15)
plt.xlabel("Awards Count",fontsize=12)
plt.ylabel("Max Salary(10m)",fontsize=12)
plt.show()
# Out:
# The correlation between max salary and awards count is 0.28
